# %%
import numpy as np
import pandas as pd
import string
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import spacy 
from wordcloud import WordCloud,STOPWORDS
from nltk.tokenize import word_tokenize
import re

# %%
df=pd.read_csv('D:/DOWNLOADS/MY INTERNSHIP/DATA/REVIEWDATA.csv',encoding="unicode_escape")
df
# Out:
#       UNIQUE ID                         DRUGNAME  \
# 0        206461                        valsartan
# 1         95260                       guanfacine
# 2         92703                           lybrel
# 3        138000                       ortho evra
# 4         35696         buprenorphine / naloxone
# ...         ...                              ...
# 5544     213178                        ofloxacin
# 5545     150835  sulfamethoxazole / trimethoprim
# 5546     164047                        ibuprofen
# 5547      77512                       cephalexin
# 5548     117277                      robaxin-750
#
#                               CONDITION  \
# 0          left ventricular disfunction
# 1                                  adhd
# 2                         birth control
# 3                         birth control
# 4                     opiate dependence
# ...                                 ...
# 5544            urinary tract infection
# 5545                         bronchitis
# ...

# %%
words = ['no side effect','pain','fever','cough','vomiting','stomach','ill','blood pressure', 'cramps','migraine','allergic','headache','drowsiness','phlegm','dizziness','weight gain','lbs','every side effect','week','dry mouth']
i = 0
while (i<5549):
    h = df["REVIEW"][i]
    jy = [w for w in words if re.search(r'\b{}\b'.format(re.escape(w)), h)]
    df ["SIDE_EFFECTS"][i] = jy
    i += 1
     
        
df.head(20)
# Out:
#     UNIQUE ID                            DRUGNAME  \
# 0      206461                           valsartan
# 1       95260                          guanfacine
# 2       92703                              lybrel
# 3      138000                          ortho evra
# 4       35696            buprenorphine / naloxone
# 5      155963                              cialis
# 6      165907                      levonorgestrel
# 7      102654                        aripiprazole
# 8       74811                              keppra
# 9       48928  ethinyl estradiol / levonorgestrel
# 10      29607                          topiramate
# 11      75612                      l-methylfolate
# 12     191290                             pentasa
# 13     221320                    dextromethorphan
# 14      98494                           nexplanon
# 15      81890                         liraglutide
# 16      48188                        trimethoprim
# 17     219869                       amitriptyline
# ...

# %%
np.array(df['SIDE_EFFECTS'])
# Out:
# array([list(['no side effect']), list(['week']), list(['week']), ...,
#        list(['pain']), list([]), list([])], dtype=object)

# %%
df.head()
# Out:
#    UNIQUE ID                  DRUGNAME                     CONDITION  \
# 0     206461                 valsartan  left ventricular disfunction
# 1      95260                guanfacine                          adhd
# 2      92703                    lybrel                 birth control
# 3     138000                ortho evra                 birth control
# 4      35696  buprenorphine / naloxone             opiate dependence
#
#                                               REVIEW  RATING  \
# 0   It has no side effect  I take it in combinati...       9
# 1   My son is halfway through his fourth week of ...       8
# 2   I used to take another oral contraceptive  wh...       5
# 3   This is my first time using any form of birth...       8
# 4   Suboxone has completely turned my life around...       9
#
#        SIDE_EFFECTS  Unnamed: 6         EFFECTIVENESS
# 0  [no side effect]         NaN   EXTREMELY EFFECTIVE
# 1            [week]         NaN        HIGH EFFECTIVE
# ...

# %%
df.to_csv('Documents/atttr.csv')

# %%
df['SIDE_EFFECTS'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# []                                           3142
# [pain]                                        594
# [week]                                        268
# [headache]                                    127
# [weight gain]                                  89
#                                              ...
# [pain, allergic, drowsiness]                    1
# [ill, headache, dizziness]                      1
# ...
